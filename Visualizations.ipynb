# %%
import pandas as pd

# %%
df = pd.read_csv('../hmda_2017_nationwide_all-records_labels.csv')
# Out:
# /Users/Rob/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (34,36,38,44,46,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['as_of_year', 'respondent_id', 'agency_name', 'agency_abbr',
#        'agency_code', 'loan_type_name', 'loan_type', 'property_type_name',
#        'property_type', 'loan_purpose_name', 'loan_purpose',
#        'owner_occupancy_name', 'owner_occupancy', 'loan_amount_000s',
#        'preapproval_name', 'preapproval', 'action_taken_name', 'action_taken',
#        'msamd_name', 'msamd', 'state_name', 'state_abbr', 'state_code',
#        'county_name', 'county_code', 'census_tract_number',
#        'applicant_ethnicity_name', 'applicant_ethnicity',
#        'co_applicant_ethnicity_name', 'co_applicant_ethnicity',
#        'applicant_race_name_1', 'applicant_race_1', 'applicant_race_name_2',
#        'applicant_race_2', 'applicant_race_name_3', 'applicant_race_3',
#        'applicant_race_name_4', 'applicant_race_4', 'applicant_race_name_5',
#        'applicant_race_5', 'co_applicant_race_name_1', 'co_applicant_race_1',
#        'co_applicant_race_name_2', 'co_applicant_race_2',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("paper")

# %%
sdf = df.sample(n=100000, random_state=0)

# %%
fig, ax = plt.subplots()
sns.countplot(x='agency_name',
              data=df,
              order=df['agency_name'].value_counts().index)
fig.autofmt_xdate()

# %%
sns.countplot(x='loan_type_name',
              data=df)

# %%
fig, ax = plt.subplots()
sns.countplot(x='property_type_name',
              data=df)
fig.autofmt_xdate()

# %%
sns.set_context("poster")
fig, ax = plt.subplots()
sns.countplot(x='loan_purpose_name',
              data=df,
              order=df['loan_purpose_name'].value_counts().index).set(xlabel="Loan Purpose", ylabel="Count")
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='owner_occupancy_name',
              data=df)
fig.autofmt_xdate()

# %%
# Filtered to loan amounts less than $1,000,000
sns.distplot(df[df['loan_amount_000s'] < 1000]['loan_amount_000s'])

# %% [markdown]
# Interesting that there are spikes near 0 (I expect that includes all loans <= $1,000) and near a little over 400. I wonder if there is a limit for some types of loans and that's the max. There also appears to be a smaller spike just past 600.

# %%
sum(df['loan_amount_000s'] == 1)
# Out:
# 32409

# %% [markdown]
# 32,409 loans were for $1,000 (or, I assume, less).

# %%
sns.countplot(x='preapproval_name',
              data=df)

# %%
# Same plot as above but filtered out 'Not applicable'
sns.countplot(x='preapproval_name',
              data=df[df['preapproval_name'] != 'Not applicable'])

# %%
sns.set_context("talk")
fig, ax = plt.subplots()
sns.countplot(x='action_taken_name',
              data=df,
              order=df['action_taken_name'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots(figsize=(14, 6))
sns.countplot(x='state_abbr',
              data=df,
              order=df['state_abbr'].value_counts().index)

# %%
fig, ax = plt.subplots()
sns.countplot(x='applicant_ethnicity_name',
              data=df)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='applicant_race_name_1',
              data=df[df['applicant_race_name_1'] != 'Information not provided by applicant in mail, Internet, or telephone application'],
              order=df[df['applicant_race_name_1'] != 'Information not provided by applicant in mail, Internet, or telephone application']['applicant_race_name_1'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='applicant_race_name_2',
              data=df,
              order=df['applicant_race_name_2'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='applicant_race_name_3',
              data=df,
              order=df['applicant_race_name_3'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='applicant_race_name_4',
              data=df,
              order=df['applicant_race_name_4'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='applicant_race_name_5',
              data=df,
              order=df['applicant_race_name_5'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='applicant_sex_name',
              data=df,
              order=df['applicant_sex_name'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='co_applicant_sex_name',
              data=df,
              order=df['co_applicant_sex_name'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='applicant_sex_name',
              data=df[df['co_applicant_sex_name'] != 'No co-applicant'],
              order=df['applicant_sex_name'].value_counts().index,
              hue='co_applicant_sex_name')
fig.autofmt_xdate()

# %%
# Filter applicant incomes down to those with under $1,000,00 in income.
sns.distplot(df[df['applicant_income_000s'] < 1000]['applicant_income_000s'])

# %%
fig, ax = plt.subplots()
sns.countplot(x='purchaser_type_name',
              data=df,
              order=df['purchaser_type_name'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='denial_reason_name_1',
              data=df,
              order=df['denial_reason_name_1'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='denial_reason_name_2',
              data=df,
              order=df['denial_reason_name_2'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='denial_reason_name_3',
              data=df,
              order=df['denial_reason_name_3'].value_counts().index)
fig.autofmt_xdate()

# %%
sns.distplot(df[df['rate_spread'] < 10]['rate_spread'])

# %%
df['rate_spread'].describe()
# Out:
# count    493273.000000
# mean          2.473063
# std           1.441981
# min           1.500000
# 25%           1.660000
# 50%           1.900000
# 75%           2.490000
# max          99.990000
# Name: rate_spread, dtype: float64

# %% [markdown]
# What is rate spread?

# %%
sns.countplot(x='hoepa_status_name',
              data=df).set_yscale('log')

# %%
fig, ax = plt.subplots()
sns.countplot(x='lien_status_name',
              data=df,
              order=df['lien_status_name'].value_counts().index)
fig.autofmt_xdate()

# %%
sns.distplot(df['population'])

# %%
# Focus more on the center of the distribution
sns.distplot(df[df['population'] < 15000]['population'])

# %%
sns.distplot(df['minority_population'])

# %%
sns.distplot(df['hud_median_family_income'])

# %% [markdown]
# Interesting that this is so jagged. I wouldn't have expected that.

# %%
sns.distplot(df['tract_to_msamd_income'])

# %%
sns.distplot(df['number_of_owner_occupied_units'])

# %%
sns.distplot(df[df['number_of_owner_occupied_units'] < 3000]['number_of_owner_occupied_units'])

# %% [markdown]
# Not sure if this is per-census tract or a different granularity.

# %%
sns.distplot(df['number_of_1_to_4_family_units'])

# %%
sns.distplot(df[df['number_of_1_to_4_family_units'] < 5000]['number_of_1_to_4_family_units'])

# %%
fig, ax = plt.subplots()
sns.countplot(x='action_taken_name',
              data=df[df['purchaser_type_name'] == 'Loan was not originated or was not sold in calendar year covered by register'],
              order=df['action_taken_name'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='action_taken_name',
              data=df,
              order=df['action_taken_name'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='loan_purpose_name',
              data=df,
              hue='action_taken_name',
              hue_order=df['action_taken_name'].value_counts().index,
              order=df['loan_purpose_name'].value_counts().index)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots()
sns.countplot(x='action_taken_name',
              data=df,
              hue='agency_name',
              order=df['action_taken_name'].value_counts().index)
fig.autofmt_xdate()
